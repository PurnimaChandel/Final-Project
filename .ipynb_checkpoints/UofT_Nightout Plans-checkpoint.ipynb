# %%
# %matplotlib notebook

# Dependencies
import json
import pprint
import requests
#import sys
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

#api keys
from config import API_Key

# %%
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer {}'.format(API_Key),}

sets = []


for idx in range(0,1000,50):
    #define some business search variables
    bus_term = 'restaurants'
    bus_location = 'University of Toronto, Toronto, Ontario'
    bus_offset = idx
    bus_limit= 50


    url_params = {
                'term': bus_term.replace(' ', '+'),
                'location': bus_location.replace(' ', '+'),
                'offset':bus_offset,
                'limit':bus_limit
                
                
                #'latitude': uoft_lat,
                #'longitude': uoft_lon
                
            }
    try:
        business_response = requests.get(url, headers=headers, params=url_params)
        business_data = business_response.json()   
        sets.append(business_data)
    
    except:
        print('EXCEPTION')
        
print(len(sets))
# Out:
# 20

# %%
new_dict = {}

for d in sets:
    for k, v in d.items():
        if new_dict.get(k) is None:
            new_dict[k] = []
        if v not in new_dict.get(k):
            new_dict[k].append(v)
print(new_dict)
# Out:
# {'businesses': [[{'id': 'qR4EIktJfQKc4rnKgBzvtw', 'alias': 'gyubee-japanese-grill-bloor-toronto', 'name': 'Gyubee Japanese Grill - Bloor', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/W2n80UrBZ017elXQ9MKD5A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/gyubee-japanese-grill-bloor-toronto?adjust_creative=5uhBD6B7pAFlJ3-6q29p5Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5uhBD6B7pAFlJ3-6q29p5Q', 'review_count': 149, 'categories': [{'alias': 'bbq', 'title': 'Barbeque'}, {'alias': 'japanese', 'title': 'Japanese'}], 'rating': 4.0, 'coordinates': {'latitude': 43.66716, 'longitude': -79.40047}, 'transactions': [], 'price': '$$', 'location': {'address1': '335 Bloor Street W', 'address2': '', 'address3': None, 'city': 'Toronto', 'zip_code': 'M5S 1W7', 'country': 'CA', 'state': 'ON', 'display_address': ['335 Bloor Street W', 'Toronto, ON M5S 1W7', 'Canada']}, 'phone': '+14165519767', 'display_phone': '+1 416-551-9767', 'distance': 585.8329754917949}, {'id': 'r_BrIgzYcwo1NAuG9dLbpg', 'alias': 'pai-northern-thai-kitchen-toronto-5', 'name': 'Pai Northern Thai Kitchen', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/t-g4d_vCAgZH_6pCqjaYWQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/pai-northern-thai-kitchen-toronto-5?adjust_creative=5uhBD6B7pAFlJ3-6q29p5Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5uhBD6B7pAFlJ3-6q29p5Q', 'review_count': 2343, 'categories': [{'alias': 'thai', 'title': 'Thai'}], 'rating': 4.5, 'coordinates': {'latitude': 43.647866, 'longitude': -79.3886415}, 'transactions': [], 'price': '$$', 'location': {'address1': '18 Duncan Street', 'address2': '', 'address3': '', 'city': 'Toronto', 'zip_code': 'M5H 3G8', 'country': 'CA', 'state': 'ON', 'display_address': ['18 Duncan Street', 'Toronto, ON M5H 3G8', 'Canada']}, 'phone': '+14169014724', 'display_phone': '+1 416-901-4724', 'distance': 1805.2989374965152}, {'id': 'eKznX8VTfcQrjCqXpeobiw', 'alias': 'rasa-toronto', 'name': 'Rasa', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zo46zVQ_UIizN9dhUbscNw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rasa-toronto?adjust_creative=5uhBD6B7pAFlJ3-6q29p5Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5uhBD6B7pAFlJ3-6q29p5Q', 'review_count': 225, 'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}], 'rating': 4.5, 'coordinates': {'latitude': 43.6627752, 'longitude': -79.4039682}, 'transactions': [], 'price': '$$', 'location': {'address1': '196 Robert Street', 'address2': '', 'address3': '', 'city': 'Toronto', 'zip_code': 'M5S 2K8', 'country': 'CA', 'state': 'ON', 'display_address': ['196 Robert Street', 'Toronto, ON M5S 2K8', 'Canada']}, 'phone': '+16473508221', 'display_phone': '+1 647-350-8221', 'distance': 667.0800791768606}, {'id': 'RtUvSWO_UZ8V3Wpj0n077w', 'alias': 'kinka-izakaya-original-toronto', 'name': 'KINKA IZAKAYA ORIGINAL', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nHFVveLBqeiCGy12R2CnRA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/kinka-izakaya-original-toronto?adjust_creative=5uhBD6B7pAFlJ3-6q29p5Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5uhBD6B7pAFlJ3-6q29p5Q', 'review_count': 1488, 'categories': [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'pubs', 'title': 'Pubs'}], 'rating': 4.0, 'coordinates': {'latitude': 43.6604, 'longitude': -79.37896}, 'transactions': ['restaurant_reservation'], 'price': '$$', 'location': {'address1': '398 Church St', 'address2': '', 'address3': '', 'city': 'Toronto', 'zip_code': 'M5B 2A2', 'country': 'CA', 'state': 'ON', 'display_address': ['398 Church St', 'Toronto, ON M5B 2A2', 'Canada']}, 'phone': '+14169770999', 'display_phone': '+1 416-977-0999', 'distance': 1386.2115558199775}, {'id': 'ro82qYK_AETB8wNGA5Xdzw', 'alias': 'kōjin-toronto', 'name': 'Kōjin', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ ...

# %%
restaurants = []
rest_info = {}

for restaurant in new_dict["businesses"]:
    
    rest_name = restaurant["name"]
    
    #account for the number of possible categories, we only want a max of 2
    numlen = len(restaurant["categories"])
    #print(numlen)
    if numlen <1:
        rest_type = "n/a"
        rest_subtype = "n/a"
    elif numlen == 1:
        rest_type = restaurant["categories"][0]["title"]
        rest_subtype = "n/a"
    elif numlen > 1:
        rest_type = restaurant["categories"][0]["title"]
        rest_subtype = restaurant["categories"][1]["title"]
    else:
        rest_type = "n/a"
        rest_subtype = "n/a"
    
    rest_lat = restaurant["coordinates"]["latitude"]
    rest_lng = restaurant["coordinates"]["longitude"]
    
    rest_distance = restaurant["distance"]   
    
     
    rest_id = restaurant["id"]
    rest_addr1 = restaurant["location"]["address1"]
    rest_addr2 = restaurant["location"]["address2"]
    rest_city = restaurant["location"]["city"]
    rest_country = restaurant["location"]["country"]
    rest_state = restaurant["location"]["state"]
    rest_zip = restaurant["location"]["zip_code"]
    
    #rest_price = restaurant["price"]
    try:
        rest_price = restaurant["price"]
        rest_price_value = rest_price.count("$")
        
        
    except:
        #print('NO $')
        rest_price = 'NO $'
        rest_price_value = 0
    
    rest_rating = restaurant["rating"]
    rest_review = restaurant["review_count"]
    
    rest_info = {"yelpid":rest_id
                ,"name":rest_name
                ,"lat":rest_lat
                ,"lng":rest_lng
                ,"distance miles": rest_distance
                ,"address1":rest_addr1
                ,"address2":rest_addr2
                ,"city":rest_city
                ,"state":rest_state
                ,"zip":rest_zip
                ,"price rating": rest_price
                ,"price value" : rest_price_value
                ,"review rating":rest_rating
                ,"review count": rest_review
                ,"type":rest_type
                ,"sub type":rest_subtype
                }
    restaurants.append(rest_info)
    
print(restaurants)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-c3a261135378> in <module>
#       4 for restaurant in new_dict["businesses"]:
#       5
# ----> 6     rest_name = restaurant["name"]
#       7
#       8     #account for the number of possible categories, we only want a max of 2
#
# TypeError: list indices must be integers or slices, not str

# %%
#build the dataframe 
restaurant_df = pd.DataFrame(restaurants)

#reorder the columns
restaurant_df = restaurant_df[['yelpid','name','lat','lng','distance miles'
                               ,'price rating','price value','review count', 'review rating'
                              ,'type','sub type','address1','city','state','zip']]
#.set_index('id',[0])
restaurant_df = restaurant_df.reset_index()
restaurant_df
# Out:
#     index                  yelpid                                       name  \
# 0       0  AVLj5MSJD1si-Rl6X6qTXQ                   Rosewood Chinese Cuisine
# 1       1  xdfGzrJ1mx3mBx6m14Ebhw                Goldstone Noodle Restaurant
# 2       2  6GlJ5Tbhht43pXIRx7ygtw                       Alex Rei Dos Leitoes
# 3       3  QrTvQw_aZOLk_8FZ8tQ_-w                             The Bier Markt
# 4       4  XudwKA_sHWiFOxaHLbnfgA                                 Green Gene
# 5       5  eW5XvdP3ApHx9v76eYCffw                              One Pear Cafe
# 6       6  98V9R-7YT20KmcmJyMiJmg                                Il Fornello
# 7       7  8BT-nH2aWf6nyIdK797OHA                      Avant Gout Restaurant
# 8       8  D87tFO-R6U8f4-e0r4Zq_g                           Yorkville Crepes
# 9       9  LynxmsOdpc_odmkSM2bA_w                         Krepesz Cafe & Bar
# 10     10  WmuoWetYC-4U2-V4taC6Wg                       Yueh Tung Restaurant
# 11     11  ANAPBJgCwEMg4ruYcQ-Law                                 Ravi Soups
# 12     12  ei7LSmqLOkiAp7aWLKD8KQ                             Saks Food Hall
# 13     13  nOmR49imE4GtmwWVLkHS9A                          Pancho y Emiliano
# 14     14  6rTzYUGghp3XHPgOGaO8UQ                   Hawthorne Food and Drink
# 15     15  5OHW43gqdoWOGWDmUmps6A                        Maja Indian Cuisine
# 16     16  CotnZvwxCubcWqsG2hK0gw                           Perla Restaurant
# 17     17  NdvUzwz3jAM7Hao_UPMu6g                  Popeyes Louisiana Kitchen
# 18     18  kMgdZVLzAXM1JQwFsPXIlg                          Indian Roti House
# 19     19  V1pdHQOPAgIWdKX9bMQWjg                                 Pizza Shab
# 20     20  3XVAfJQdX327pqNZg5KV5g                       Bazara Asian Cuisine
# 21     21  2xn5cEvhZFxFRcnxhcT0Yw                              Planta Burger
# 22     22  lDkKSL4AT2faZwClvCvLnw             Golden Diner Family Restaurant
# 23     23  PFLnr1C9K9FHQc-GOvtnHQ                            Village Juicery
# 24     24  HSPMT3m9OOD4ypMO4wwOdg                             Fresh On Front
# 25     25  9DLBwCS4hu_xaiENCbYXbQ         Chae Chester Fried Chicken Express
# 26     26  3xUoXuEgJhHlSgBsSfKeCQ                               W Burger Bar
# 27     27  JePdoHGJ2kWRQkfGx0T34Q                  Churrasqueira Do Sardinha
# 28     28  ACmcdphAR4UpOeHa6oQe9A                     Chinese Dumpling House
# 29     29  BJ7lAnKYnqEs-Jjx7_twXA                                 Sid's Cafe
# 30     30  UpEVdq_euH-5mqCIgUAd2Q                       Le Papillon On Front
# 31     31  buMP3nR_-EL2ROE7nKMBUg  Wafflian - Belgian Waffle and Cupcake Bar
# 32     32  SxjNgkzAlUG-wt2rSbc2HQ                                New Ho King
# 33     33  a1WWhLOWUC3wZLhkXdAIJQ                                French Made
# 34     34  sS8uO7UuWcW_17AMga4yKg                               Nutella Cafe
# 35     35  35Mdu_9unGIn4pMoQByWFQ                      Signatures Restaurant
# 36     36  i2sSSIrgQg1fVjqYXZLvNA                         PAT Central Market
# 37     37  oOGLDf2rzeCPS7UQ8hhPlQ                                      SU&BU
# 38     38  bAU0v3UqPS20qMGwgI5rCg                      Pilot Coffee Roasters
# 39     39  gWainRDwQaDg7YRZAaotdw                          Kasai Grill House
# 40     40  Vf_RHj0f1VViEF6OYnEfUA             Quinn's Steakhouse & Irish Bar
# 41     41  XBKhVOYDA3AaAN6k3TOijQ                        The Burger's Priest
# 42     42  kQGJ5QUJ0BAIpmYYtf7Uqw                       Upper Deck By Fran's
# 43     43  g6CiDcpi2OPycTUORSoXEA                               Ramen Misoya
# 44     44  P458E2QRUgrCTWZfKoO7bg                              Hangry Burger
# 45     45  x7V4wx8O_5EWP1SacNtWSQ                  Flock Rotisserie + Greens
# 46     46  TFtObYQyEnZ0kpPWOn7YDw                             Pizzeria Bosco
# 47     47  jeWIm7obsv14C6JHh1OadA                          Home Of Hot Taste
# 48     48  VAE8gdXm7JAml0CLTs3kNA                      O'Grady's Tap & Grill
# 49     49  7T1XVTSocHcOu2H5v2Iqog                           Smoke's Weinerie
#
#           lat        lng  distance miles price rating  price value  \
# 0   43.653109 -79.396713     1133.480521           $$            2
# 1   43.652152 -79.397964     1250.303686            $            1
# 2   43.648930 -79.420190     2553.489424            $            1
# 3   43.644740 -79.399920     2076.896788           $$            2
# 4   43.655350 -79.384400     1263.814537         NO $            0
# 5   43.654820 -79.387270     1157.689378         NO $            0
# 6   43.647570 -79.386840     1888.932884           $$            2
# 7   43.678640 -79.390450     1757.678362         NO $            0
# 8   43.672193 -79.387866     1174.948256           $$            2
# 9   43.655110 -79.402020     1042.423934           $$            2
# 10  43.655088 -79.385179     1243.319927           $$            2
# 11  43.647700 -79.392010     1769.603828           $$            2
# 12  43.651791 -79.380199     1785.202851           $$            2
# 13  43.654380 -79.402190     1118.840902           $$            2
# 14  43.652368 -79.376226     1981.600312           $$            2
# 15  43.671532 -79.377937     1663.724986           $$            2
# 16  43.655490 -79.411480     1538.399767           $$            2
# 17  43.657680 -79.399550      698.701361            $            1
# 18  43.664471 -79.380043     1249.072438           $$            2
# 19  43.657200 -79.378320     1546.069598          $$$            3
# 20  43.648497 -79.420596     2590.497775           $$            2
# 21  43.651150 -79.379290     1898.548764           $$            2
# 22  43.662030 -79.377320     1478.030146           $$            2
# 23  43.656040 -79.411300     1493.604000           $$            2
# 24  43.648266 -79.374338     2395.921047          $$$            3
# 25  43.671100 -79.375090     1869.579146            $            1
# 26  43.661462 -79.383643      990.974264           $$            2
# 27  43.655060 -79.418080     2019.659778            $            1
# 28  43.664350 -79.414110     1492.438024         NO $            0
# 29  43.662479 -79.398750      253.207387         NO $            0
# 30  43.648430 -79.373270     2457.012239           $$            2
# 31  43.653743 -79.391033     1124.652689           $$            2
# 32  43.656110 -79.399670      854.369641           $$            2
# 33  43.645344 -79.392254     2013.183984           $$            2
# 34  43.661961 -79.379838     1284.638410            $            1
# 35  43.668710 -79.396360      586.094999          $$$            3
# 36  43.663810 -79.416210     1655.454407            $            1
# 37  43.647245 -79.390158     1837.621001           $$            2
# 38  43.645520 -79.380310     2345.819832            $            1
# 39  43.655320 -79.416150     1869.394131           $$            2
# 40  43.650880 -79.383180     1701.315641          $$$            3
# 41  43.666036 -79.407864     1025.063333           $$            2
# 42  43.661469 -79.384068      957.359819           $$            2
# 43  43.646839 -79.406306     2016.954656         NO $            0
# 44  43.660920 -79.382660     1088.026769           $$            2
# 45  43.670439 -79.382723     1313.185902           $$            2
# 46  43.657093 -79.387600      947.533910         NO $            0
# 47  43.664340 -79.415660     1611.434059           $$            2
# 48  43.658880 -79.393760      511.346232           $$            2
# 49  43.658310 -79.399810      643.720185            $            1
#
#     review count  review rating                    type  \
# 0            202            3.0                 Chinese
# 1            114            3.0                 Chinese
# 2             19            4.0              Sandwiches
# 3            184            3.0                    Bars
# 4              1            4.0               Taiwanese
# 5             37            2.5                   Cafes
# 6             89            3.0                 Italian
# 7             14            3.5                  French
# 8            158            3.5               Creperies
# 9             78            3.5               Creperies
# 10           176            3.5                   Hakka
# 11            55            4.0                    Soup
# 12            22            4.0              Food Court
# 13            92            3.5                 Mexican
# 14            69            3.5          Canadian (New)
# 15            25            3.5                  Indian
# 16            14            3.5              Portuguese
# 17            15            2.5           Chicken Wings
# 18            34            3.5                  Indian
# 19             9            4.0                   Halal
# 20           108            4.0            Asian Fusion
# 21            57            3.5                 Burgers
# 22            34            3.5                   Greek
# 23            16            5.0  Juice Bars & Smoothies
# 24            34            4.0              Vegetarian
# 25             8            3.5             Restaurants
# 26           273            3.5                 Burgers
# 27            14            3.5              Portuguese
# 28             4            5.0                 Chinese
# 29             2            2.5                   Cafes
# 30           147            3.5                  French
# 31            24            3.5                 Waffles
# 32           162            2.5                 Chinese
# 33            19            4.0                   Cafes
# 34            10            4.0               Creperies
# 35            10            3.0          Canadian (New)
# 36            85            4.0                 Grocery
# 37           148            3.5              Sushi Bars
# 38            38            4.0                   Cafes
# 39            66            3.5                  Korean
# 40           100            3.5                   Irish
# 41            33            3.0                 Burgers
# 42            36            3.0                    Bars
# 43            45            4.0                   Ramen
# 44            20            3.5                 Burgers
# 45            26            3.5                   Salad
# 46             3            4.5                   Pizza
# 47            39            3.5                  Korean
# 48            42            2.5                    Pubs
# 49            11            2.0             Poutineries
#
#                   sub type               address1     city state      zip
# 0       Tapas/Small Plates    463 Dundas Street W  Toronto    ON  M5T 1G8
# 1                  Noodles     266 Spadina Avenue  Toronto    ON  M5T 2E4
# 2               Portuguese       219 Av Ossington  Toronto    ON  M6J 2Z8
# 3     Beer, Wine & Spirits       600 King St West  Toronto    ON  M5V 1M3
# 4                      n/a    121 Dundas Street W  Toronto    ON      M5G
# 5                      n/a    201 Dundas Street W  Toronto    ON  M5G 1C8
# 6                      n/a      214 King Street W  Toronto    ON  M5H 3S6
# 7                      n/a      1108 Yonge Street  Toronto    ON  M4W 2L6
# 8                    Cafes    18 Yorkville Avenue  Toronto    ON  M4W 3Y8
# 9                    Cafes     253 Augusta Avenue  Toronto    ON  M5T 2L8
# 10      Breakfast & Brunch   126 Elizabeth Street  Toronto    ON  M5G 1P5
# 11                     n/a  322 Adelaide Street W  Toronto    ON  M5V 1R1
# 12                     n/a       176 Yonge Street  Toronto    ON  M5C 2L7
# 13                     n/a        200 Augusta Ave  Toronto    ON  M5T 2L8
# 14                Caterers   60 Richmond Street E  Toronto    ON  M5C 1N8
# 15                     n/a     345 Bloor Street E  Toronto    ON      M4W
# 16                     n/a         539 College St  Toronto    ON  M6G 1A9
# 17               Fast Food     267 College Street  Toronto    ON  M5T 1R6
# 18                     n/a      471 Church Street  Toronto    ON  M4Y 2C5
# 19                   Pizza        113 Bond Street  Toronto    ON  M5B 1Y2
# 20              Sushi Bars   188 Ossington Avenue  Toronto    ON  M6J 2Z7
# 21                Desserts    4 Temperance Street  Toronto    ON  M5H 1Y4
# 22                  Diners     105 Carlton Street  Toronto    ON  M5B 1M1
# 23           Live/Raw Food     540 College Street  Toronto    ON  M6G 1A6
# 24                     n/a      47 Front Street E  Toronto    ON  M5E 1B3
# 25                     n/a       23 Howard Street  Toronto    ON  M4X 1J6
# 26      Breakfast & Brunch      10 College Street  Toronto    ON  M5G 1K2
# 27                  French   707 College Street W  Toronto    ON  M6G 1C2
# 28                     n/a       623 Bloor Street  Toronto    ON  M6G 1K8
# 29                     n/a  100 St. George Street  Toronto    ON  M5S 3G3
# 30      Breakfast & Brunch      69 Front Street E  Toronto    ON  M5E 1B5
# 31                     n/a      109 McCaul Street  Toronto    ON  M5T 3K5
# 32                     n/a        410 Spadina Ave  Toronto    ON  M5T 2G7
# 33                Bakeries       80 Blue Jays Way  Toronto    ON  M5V 2G3
# 34                   Cafes      60 Carlton Street  Toronto    ON  M5B 1J2
# 35                     n/a         220 Bloor St W  Toronto    ON  M5S 1W2
# 36                  Korean     675 Bloor Street W  Toronto    ON  M6G 1L3
# 37                     n/a        106 John Street  Toronto    ON  M5H 1X9
# 38                     n/a      65 Front Street W  Toronto    ON  M5J 1E6
# 39                Barbeque     650 College Street  Toronto    ON  M6G 1B8
# 40             Steakhouses    The Sheraton Centre  Toronto    ON  M5H 2A3
# 41                     n/a     406 Bloor Street W  Toronto    ON  M5S 1X5
# 42  American (Traditional)    2-20 College Street  Toronto    ON  M5G 1K2
# 43                     n/a     646 Queen Street W  Toronto    ON  M6J 1E4
# 44                     n/a       437 Yonge Street  Toronto    ON  M5B 1T3
# 45                     n/a     175 Bloor Street E  Toronto    ON  M4W 3R8
# 46                     n/a   Toronto Eaton Centre  Toronto    ON  M5H 3X4
# 47                     n/a     658 Bloor Street W  Toronto    ON  M6G 1K9
# 48                   Irish     171 College Street  Toronto    ON  M5T 1P7
# 49                   Delis     457 Spadina Avenue  Toronto    ON  M5S 2G7

# %%
restaurant_df.to_csv("UofT_NightOuts.csv")

# %%
#setup some variables for the reviews
yelp_reviews = []
reviews_info = {}
yelp_id=[]
for index, row in restaurant_df.iterrows():
    yid = restaurant_df["yelpid"]
    #restaurant name
    yname = row[2]
    yelp_id.append(yid)

len(yelp_id)    
    
for i in yelp_id:
    base_url = 'https://api.yelp.com/v3/businesses/'
    review_url= base_url+i+'/reviews'
    review_headers = {'Authorization': 'Bearer {}'.format(API_Key),}
        
try:
    review_response = requests.get(review_url, headers=review_headers)
    review_responsetype = review_response.status_code
    review_data = review_response.json()
    print(review_data)
    
except:
    print('EXCEPTION')
# Out:
# EXCEPTION

# %%
for review in review_data["reviews"]:
    rest_id = yid
    rest_name= yname
    ls_review_id = review["id"]
    ls_review_rating = review["rating"]
    ls_review_text = review["text"]
    ls_review_timestamp = review["time_created"]
        
    #add yelp review name and review id
    # ls_review_name = review["user"]["name"]
    #ls_review_reviewerid = review["user"]["id"]
        
        
        #check to see if we have text to parse
        #print(ls_review_text)
        
        #--->VADER
        
#         #run vader analysis on each text
#         results = analyzer.polarity_scores(ls_review_text)
#         com = results["compound"]
#         pos = results["pos"]
#         neg = results["neg"]
#         neu = results["neu"]
       
#         #add each value to each list
#         com_ls.append(com)
#         pos_ls.append(pos)
#         neg_ls.append(neg)
#         neu_ls.append(neu)
#         #--------END VADER
        

        
    reviews_info = {"yelpid":rest_id
                    ,"name": rest_name
                    ,"reviewid": ls_review_id
                    ,"review text": ls_review_text
                    ,"timestamp": ls_review_timestamp}
                   
    yelp_reviews.append(reviews_info)
    print(yelp_reviews)
# Out:
# [{'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '7ZBbshcb3VMqfwmkNfuHZQ', 'review text': 'Not sure why anyone would go here when Clubhouse is next door. Unfortunately for me, it was unexpectedly closed so I had to settle for some dressed up...', 'timestamp': '2018-12-27 13:09:19', 'reviewer name': 'Armen A.', 'reviewer id': 'IN1YSPjd7-5QthMM7EYyFA'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '93_HDm3TOrDYcrPIphNmmQ', 'review text': "Their specialty does not come in snack size. WHY. I can't finish a regular. \n\nI never really liked their poutine, their fries are really really soggy and...", 'timestamp': '2016-08-18 06:52:41', 'reviewer name': 'Irene T.', 'reviewer id': 'UXpTrzITc0yg08sXftsa-w'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': 'Em8ADPYe150y-weAFpHfwQ', 'review text': 'Apparently this place is much better at 4:00a (according to some locals). However, as a tourist visiting the Toronto area, the fact that "poutineries" is...', 'timestamp': '2017-10-10 20:31:50', 'reviewer name': 'Jason W.', 'reviewer id': 'wu8Qh6QzgdoFuXux59p8QA'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': 'Em8ADPYe150y-weAFpHfwQ', 'review text': 'Apparently this place is much better at 4:00a (according to some locals). However, as a tourist visiting the Toronto area, the fact that "poutineries" is...', 'timestamp': '2017-10-10 20:31:50'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '7ZBbshcb3VMqfwmkNfuHZQ', 'review text': 'Not sure why anyone would go here when Clubhouse is next door. Unfortunately for me, it was unexpectedly closed so I had to settle for some dressed up...', 'timestamp': '2018-12-27 13:09:19'}]
# [{'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '7ZBbshcb3VMqfwmkNfuHZQ', 'review text': 'Not sure why anyone would go here when Clubhouse is next door. Unfortunately for me, it was unexpectedly closed so I had to settle for some dressed up...', 'timestamp': '2018-12-27 13:09:19', 'reviewer name': 'Armen A.', 'reviewer id': 'IN1YSPjd7-5QthMM7EYyFA'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '93_HDm3TOrDYcrPIphNmmQ', 'review text': "Their specialty does not come in snack size. WHY. I can't finish a regular. \n\nI never really liked their poutine, their fries are really really soggy and...", 'timestamp': '2016-08-18 06:52:41', 'reviewer name': 'Irene T.', 'reviewer id': 'UXpTrzITc0yg08sXftsa-w'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': 'Em8ADPYe150y-weAFpHfwQ', 'review text': 'Apparently this place is much better at 4:00a (according to some locals). However, as a tourist visiting the Toronto area, the fact that "poutineries" is...', 'timestamp': '2017-10-10 20:31:50', 'reviewer name': 'Jason W.', 'reviewer id': 'wu8Qh6QzgdoFuXux59p8QA'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': 'Em8ADPYe150y-weAFpHfwQ', 'review text': 'Apparently this place is much better at 4:00a (according to some locals). However, as a tourist visiting the Toronto area, the fact that "poutineries" is...', 'timestamp': '2017-10-10 20:31:50'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '7ZBbshcb3VMqfwmkNfuHZQ', 'review text': 'Not sure why anyone would go here when Clubhouse is next door. Unfortunately for me, it was unexpectedly closed so I had to settle for some dressed up...', 'timestamp': '2018-12-27 13:09:19'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '93_HDm3TOrDYcrPIphNmmQ', 'review text': "Their specialty does not come in snack size. WHY. I can't finish a regular. \n\nI never really liked their poutine, their fries are really really soggy and...", 'timestamp': '2016-08-18 06:52:41'}]
# [{'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '7ZBbshcb3VMqfwmkNfuHZQ', 'review text': 'Not sure why anyone would go here when Clubhouse is next door. Unfortunately for me, it was unexpectedly closed so I had to settle for some dressed up...', 'timestamp': '2018-12-27 13:09:19', 'reviewer name': 'Armen A.', 'reviewer id': 'IN1YSPjd7-5QthMM7EYyFA'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '93_HDm3TOrDYcrPIphNmmQ', 'review text': "Their specialty does not come in snack size. WHY. I can't finish a regular. \n\nI never really liked their poutine, their fries are really really soggy and...", 'timestamp': '2016-08-18 06:52:41', 'reviewer name': 'Irene T.', 'reviewer id': 'UXpTrzITc0yg08sXftsa-w'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': 'Em8ADPYe150y-weAFpHfwQ', 'review text': 'Apparently this place is much better at 4:00a (according to some locals). However, as a tourist visiting the Toronto area, the fact that "poutineries" is...', 'timestamp': '2017-10-10 20:31:50', 'reviewer name': 'Jason W.', 'reviewer id': 'wu8Qh6QzgdoFuXux59p8QA'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': 'Em8ADPYe150y-weAFpHfwQ', 'review text': 'Apparently this place is much better at 4:00a (according to some locals). However, as a tourist visiting the Toronto area, the fact that "poutineries" is...', 'timestamp': '2017-10-10 20:31:50'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '7ZBbshcb3VMqfwmkNfuHZQ', 'review text': 'Not sure why anyone would go here when Clubhouse is next door. Unfortunately for me, it was unexpectedly closed so I had to settle for some dressed up...', 'timestamp': '2018-12-27 13:09:19'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': '93_HDm3TOrDYcrPIphNmmQ', 'review text': "Their specialty does not come in snack size. WHY. I can't finish a regular. \n\nI never really liked their poutine, their fries are really really soggy and...", 'timestamp': '2016-08-18 06:52:41'}, {'yelpid': '7T1XVTSocHcOu2H5v2Iqog', 'name': "Smoke's Weinerie", 'reviewid': 'Em8ADPYe150y-weAFpHfwQ', 'review text': 'Apparently this place is much better at 4:00a (according to some locals). However, as a tourist visiting the Toronto area, the fact that "poutineries" is...', 'timestamp': '2017-10-10 20:31:50'}]

# %%
reviews_df = pd.DataFrame(yelp_reviews)
reviews_df
# Out:
#                name                                        review text  \
# 0  Smoke's Weinerie  Not sure why anyone would go here when Clubhou...
# 1  Smoke's Weinerie  Their specialty does not come in snack size. W...
# 2  Smoke's Weinerie  Apparently this place is much better at 4:00a ...
# 3  Smoke's Weinerie  Apparently this place is much better at 4:00a ...
# 4  Smoke's Weinerie  Not sure why anyone would go here when Clubhou...
# 5  Smoke's Weinerie  Their specialty does not come in snack size. W...
# 6  Smoke's Weinerie  Apparently this place is much better at 4:00a ...
#
#               reviewer id reviewer name                reviewid  \
# 0  IN1YSPjd7-5QthMM7EYyFA      Armen A.  7ZBbshcb3VMqfwmkNfuHZQ
# 1  UXpTrzITc0yg08sXftsa-w      Irene T.  93_HDm3TOrDYcrPIphNmmQ
# 2  wu8Qh6QzgdoFuXux59p8QA      Jason W.  Em8ADPYe150y-weAFpHfwQ
# 3                     NaN           NaN  Em8ADPYe150y-weAFpHfwQ
# 4                     NaN           NaN  7ZBbshcb3VMqfwmkNfuHZQ
# 5                     NaN           NaN  93_HDm3TOrDYcrPIphNmmQ
# 6                     NaN           NaN  Em8ADPYe150y-weAFpHfwQ
#
#              timestamp                  yelpid
# 0  2018-12-27 13:09:19  7T1XVTSocHcOu2H5v2Iqog
# 1  2016-08-18 06:52:41  7T1XVTSocHcOu2H5v2Iqog
# 2  2017-10-10 20:31:50  7T1XVTSocHcOu2H5v2Iqog
# 3  2017-10-10 20:31:50  7T1XVTSocHcOu2H5v2Iqog
# 4  2018-12-27 13:09:19  7T1XVTSocHcOu2H5v2Iqog
# 5  2016-08-18 06:52:41  7T1XVTSocHcOu2H5v2Iqog
# 6  2017-10-10 20:31:50  7T1XVTSocHcOu2H5v2Iqog
